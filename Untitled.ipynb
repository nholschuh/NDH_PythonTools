# %%
import sys
sys.path.append('/mnt/data01/Code/')
import NDH_Tools as ndh

season_opts = ndh.loadmat('season_metadata.mat',debug_flag=1)
# Out:
# Trying Method 1 with no described variables
# Trying Method 2

# %%
season_opts
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Wed Jul 17 15:52:29 2024',
#  '__version__': '1.0',
#  '__globals__': [],
#  'a_dates': array([[731546,      1],
#         [731548,      1],
#         [731554,      1],
#         [731556,      1],
#         [731562,      1],
#         [732269,      2],
#         [732272,      2],
#         [732278,      2],
#         [732280,      2],
#         [732680,      3],
#         [732681,      3],
#         [732682,      3],
#         [732683,      3],
#         [732684,      3],
#         [734062,      4],
#         [734064,      4],
#         [734066,      4],
#         [734071,      4],
#         [734075,      4],
#         [734077,      4],
#         [734079,      4],
#         [734080,      4],
#         [734081,      4],
#         [734082,      4],
#         [734084,      4],
#         [734086,      4],
#         [734089,      4],
#         [734092,      4],
#         [734093,      4],
#         [734095,      4],
# ...
